# %%
from mylib import MVPA

# %%
subjects = ["s105","s107"]
mask_fname = ["IPS_mask.nii"]
for i in range(len(subjects)):
    for j in range(len(mask_fname)):
        results = MVPA(subjects[i],mask_fname[j])
        print
        print "***********************************"
        print 
        print "This is my results:", results
        print
        print "***********************************"
        print
# Out:
# sample_number= 320
# feature_number= 152256
# data_info= (320, 152256)
# sample_number= 320
# feature_number= 199
# data_info= (320, 199)
# TR_index= [0 1 2 3 4]
# Actual time of TR= [0. 2. 4. 6. 8.]
# ori_voxel_feature= [[11 38 34]
#  [11 39 34]
#  [11 42 32]
#  [12 38 35]
#  [12 39 33]]
# voxel_size= (3.125, 3.125, 3.125)
# volumes_dim= (52, 61, 48)
# Dataset: 320x199@float32, <sa: chunks,targets,time_coords,time_indices>, <fa: voxel_indices>, <a: imgaffine,imghdr,imgtype,mapper,voxel_dim,voxel_eldim>
# stats: mean=4.60088e-06 std=0.635381 var=0.403709 min=-2.82601 max=3.00302
#
# Counts of targets in each chunk:
#   chunks\targets 0.0 1.0 2.0 3.0 4.0
#                  --- --- --- --- ---
#        1.0        56  6   6   6   6
#        2.0        56  6   6   6   6
#        3.0        56  6   6   6   6
#        4.0        56  6   6   6   6
#
# Summary for targets across chunks
#   targets mean std min max #chunks
#     0      56   0   56  56    4
#     1       6   0   6   6     4
#     2       6   0   6   6     4
#     3       6   0   6   6     4
#     4       6   0   6   6     4
#
# Summary for chunks across targets
#   chunks mean std min max #targets
#     1     16   20  6   56     5
#     2     16   20  6   56     5
#     3     16   20  6   56     5
#     4     16   20  6   56     5
# Sequence statistics for 320 entries from set [0.0, 1.0, 2.0, 3.0, 4.0]
# Counter-balance table for orders up to 2:
# Targets/Order  O1              |   O2              |
#      0.0:     127 24 24 24 24  |  190  8  8  8  8  |
#      1.0:      24  0  0  0  0  |   8  16  0  0  0  |
#      2.0:      24  0  0  0  0  |   8   0 16  0  0  |
#      3.0:      24  0  0  0  0  |   8   0  0 16  0  |
#      4.0:      24  0  0  0  0  |   8   0  0  0 16  |
# Correlations: min=-0.33 max=0.82 mean=-0.0031 sum(abs)=1.1e+02
# Mean accuracy KNN_Orig= 0.3125
#
# t_value= [1.73205081]
# p_value_orig= [0.18169011]
#
# Accuracy for each run= [[0.33333333]
#  [0.375     ]
#  [0.20833333]
#  [0.33333333]]
# Mean accuracy SVM_orig= 0.3645833333333333
#
#
# t_value_svm= [1.6646298]
# p_value_svm= [0.1945755]
# Mean accuracy GNB_orig= 0.3333333333333333
#
#
# t_new_value_gnb= [4.89897949]
# p_new_value_gnb= [0.0162766]
# Dataset: 320x199@float32, <sa: chunks,targets,time_coords,time_indices>, <fa: voxel_indices>, <a: imgaffine,imghdr,imgtype,mapper,voxel_dim,voxel_eldim>
# stats: mean=4.60088e-06 std=0.635381 var=0.403709 min=-2.82601 max=3.00302
#
# Counts of targets in each chunk:
#   chunks\targets 0.0 1.0 2.0 3.0 4.0
#                  --- --- --- --- ---
#        1.0        56  6   6   6   6
#        2.0        56  6   6   6   6
#        3.0        56  6   6   6   6
#        4.0        56  6   6   6   6
#
# Summary for targets across chunks
#   targets mean std min max #chunks
#     0      56   0   56  56    4
#     1       6   0   6   6     4
#     2       6   0   6   6     4
#     3       6   0   6   6     4
#     4       6   0   6   6     4
#
# Summary for chunks across targets
#   chunks mean std min max #targets
#     1     16   20  6   56     5
#     2     16   20  6   56     5
#     3     16   20  6   56     5
#     4     16   20  6   56     5
# Sequence statistics for 320 entries from set [0.0, 1.0, 2.0, 3.0, 4.0]
# Counter-balance table for orders up to 2:
# Targets/Order  O1              |   O2              |
#      0.0:     127 24 24 24 24  |  190  8  8  8  8  |
#      1.0:      24  0  0  0  0  |   8  16  0  0  0  |
#      2.0:      24  0  0  0  0  |   8   0 16  0  0  |
#      3.0:      24  0  0  0  0  |   8   0  0 16  0  |
#      4.0:      24  0  0  0  0  |   8   0  0  0 16  |
# Correlations: min=-0.33 max=0.82 mean=-0.0031 sum(abs)=1.1e+02
# (320, 199)
# (320, 5)
# [[0.00221397 0.0054483  0.00981248 0.02122924 0.02163589]
#  [0.00224287 0.00549555 0.01020045 0.02215605 0.02261027]
#  [0.00208297 0.00356881 0.00596275 0.00294315 0.00431884]
#  ...
#  [0.00305044 0.00705972 0.01692519 0.02664927 0.02385159]
#  [0.00279536 0.00467038 0.00802686 0.00297547 0.00225358]
#  [0.00231135 0.0031905  0.00456841 0.00264349 0.00292848]]
# Mean Accuracy KNN_new= 0.3125
#
# t_new_value= [1.26025208]
# p_new_value= [0.29668937]
#
# Accuracy for each run= [[0.375     ]
#  [0.33333333]
#  [0.16666667]
#  [0.375     ]]
# Mean accuracy SVM= 0.37499999999999994
#
#
# t_new_value_svm= [1.26025208]
# p_new_value_svm= [0.29668937]
# Mean accuracy GNB= 0.3333333333333333
#
#
# t_new_value_gnb= [1.35873244]
# p_new_value_gnb= [0.26736717]
#
# ****************************
#
# This is my results: (0.3125, 0.3645833333333333, 0.3333333333333333, 0.3125, 0.37499999999999994, 0.3333333333333333)
#
# ****************************
#
# sample_number= 320
# feature_number= 152256
# data_info= (320, 152256)
# sample_number= 320
# feature_number= 199
# data_info= (320, 199)
# TR_index= [0 1 2 3 4]
# Actual time of TR= [0. 2. 4. 6. 8.]
# ori_voxel_feature= [[11 38 34]
#  [11 39 34]
#  [11 42 32]
#  [12 38 35]
#  [12 39 33]]
# voxel_size= (3.125, 3.125, 3.125)
# volumes_dim= (52, 61, 48)
# Dataset: 320x199@float32, <sa: chunks,targets,time_coords,time_indices>, <fa: voxel_indices>, <a: imgaffine,imghdr,imgtype,mapper,voxel_dim,voxel_eldim>
# stats: mean=1.30355e-05 std=0.911723 var=0.831239 min=-5.10269 max=8.05689
#
# Counts of targets in each chunk:
#   chunks\targets 0.0 1.0 2.0 3.0 4.0
#                  --- --- --- --- ---
#        1.0        56  6   6   6   6
#        2.0        56  6   6   6   6
#        3.0        56  6   6   6   6
#        4.0        56  6   6   6   6
#
# Summary for targets across chunks
#   targets mean std min max #chunks
#     0      56   0   56  56    4
#     1       6   0   6   6     4
#     2       6   0   6   6     4
#     3       6   0   6   6     4
#     4       6   0   6   6     4
#
# Summary for chunks across targets
#   chunks mean std min max #targets
#     1     16   20  6   56     5
#     2     16   20  6   56     5
#     3     16   20  6   56     5
#     4     16   20  6   56     5
# Sequence statistics for 320 entries from set [0.0, 1.0, 2.0, 3.0, 4.0]
# Counter-balance table for orders up to 2:
# Targets/Order  O1              |   O2              |
#      0.0:     127 24 24 24 24  |  190  8  8  8  8  |
#      1.0:      24  0  0  0  0  |   8  16  0  0  0  |
#      2.0:      24  0  0  0  0  |   8   0 16  0  0  |
#      3.0:      24  0  0  0  0  |   8   0  0 16  0  |
#      4.0:      24  0  0  0  0  |   8   0  0  0 16  |
# Correlations: min=-0.33 max=0.82 mean=-0.0031 sum(abs)=1.1e+02
# Mean accuracy KNN_Orig= 0.18750000000000003
#
# t_value= [-1.19207912]
# p_value_orig= [0.31893179]
#
# Accuracy for each run= [[0.04166667]
#  [0.20833333]
#  [0.29166667]
#  [0.20833333]]
# Mean accuracy SVM_orig= 0.26041666666666663
#
#
# t_value_svm= [0.24253563]
# p_value_svm= [0.82400101]
# Mean accuracy GNB_orig= 0.29166666666666663
#
#
# t_new_value_gnb= [0.81649658]
# p_new_value_gnb= [0.47402139]
# Dataset: 320x199@float32, <sa: chunks,targets,time_coords,time_indices>, <fa: voxel_indices>, <a: imgaffine,imghdr,imgtype,mapper,voxel_dim,voxel_eldim>
# stats: mean=1.30355e-05 std=0.911723 var=0.831239 min=-5.10269 max=8.05689
#
# Counts of targets in each chunk:
#   chunks\targets 0.0 1.0 2.0 3.0 4.0
#                  --- --- --- --- ---
#        1.0        56  6   6   6   6
#        2.0        56  6   6   6   6
#        3.0        56  6   6   6   6
#        4.0        56  6   6   6   6
#
# Summary for targets across chunks
#   targets mean std min max #chunks
#     0      56   0   56  56    4
#     1       6   0   6   6     4
#     2       6   0   6   6     4
#     3       6   0   6   6     4
#     4       6   0   6   6     4
#
# Summary for chunks across targets
#   chunks mean std min max #targets
#     1     16   20  6   56     5
#     2     16   20  6   56     5
#     3     16   20  6   56     5
#     4     16   20  6   56     5
# Sequence statistics for 320 entries from set [0.0, 1.0, 2.0, 3.0, 4.0]
# Counter-balance table for orders up to 2:
# Targets/Order  O1              |   O2              |
#      0.0:     127 24 24 24 24  |  190  8  8  8  8  |
#      1.0:      24  0  0  0  0  |   8  16  0  0  0  |
#      2.0:      24  0  0  0  0  |   8   0 16  0  0  |
#      3.0:      24  0  0  0  0  |   8   0  0 16  0  |
#      4.0:      24  0  0  0  0  |   8   0  0  0 16  |
# Correlations: min=-0.33 max=0.82 mean=-0.0031 sum(abs)=1.1e+02
# (320, 199)
# (320, 5)
# [[0.00544221 0.00713101 0.02227221 0.02106711 0.01769012]
#  [0.00546155 0.00710763 0.02168904 0.02043834 0.01720236]
#  [0.00390957 0.00576543 0.00864957 0.00725512 0.00539747]
#  ...
#  [0.01343779 0.02592153 0.0652769  0.14693582 0.16930985]
#  [0.00811878 0.01834155 0.03742843 0.04127894 0.0324229 ]
#  [0.00845297 0.01437941 0.03851881 0.07294923 0.07310677]]
# Mean Accuracy KNN_new= 0.19791666666666666
#
# t_new_value= [-1.46385011]
# p_new_value= [0.2394426]
#
# Accuracy for each run= [[0.125     ]
#  [0.20833333]
#  [0.29166667]
#  [0.16666667]]
# Mean accuracy SVM= 0.26041666666666663
#
#
# t_new_value_svm= [-1.46385011]
# p_new_value_svm= [0.2394426]
# Mean accuracy GNB= 0.2604166666666667
#
#
# t_new_value_gnb= [0.26413527]
# p_new_value_gnb= [0.80878149]
#
# ****************************
#
# This is my results: (0.18750000000000003, 0.26041666666666663, 0.29166666666666663, 0.19791666666666666, 0.26041666666666663, 0.2604166666666667)
#
# ****************************
